# %% [markdown]
# **Working with JSON**

# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the 'D:\JupyterEnv\myenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ...

# %%
pd.read_json('https://api.coindesk.com/v1/bpi/currentprice.json')
# Out:
#                                  time  \
# updated     Sep 21, 2024 04:24:38 UTC
# updatedISO  2024-09-21T04:24:38+00:00
# updateduk   Sep 21, 2024 at 05:24 BST
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
# EUR         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# ...

# %% [markdown]
# **Working with SQL**

# %%
# !pip install mysql.connector
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the 'D:\JupyterEnv\myenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import  mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
pd.read_sql_query("SELECT * FROM COUNTRYLANGUAGE where  Percentage >0.05 AND LANGUAGE = 'ENGLISH' AND COUNTRYCODE = 'USA'",conn)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10772\1788668106.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM COUNTRYLANGUAGE where  Percentage >0.05 AND LANGUAGE = 'ENGLISH' AND COUNTRYCODE = 'USA'",conn)
#   CountryCode Language IsOfficial  Percentage
# 0         USA  English          T        86.2

# %%
pd.read_sql_query("SELECT * FROM CITY WHERE COUNTRYCODE = 'USA' AND DISTRICT = 'CALIFORNIA' ORDER BY POPULATION ASC  ",conn)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10772\1403873908.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM CITY WHERE COUNTRYCODE = 'USA' AND DISTRICT = 'CALIFORNIA' ORDER BY POPULATION ASC  ",conn)
#       ID           Name CountryCode    District  Population
# 0   4065         Carson         USA  California       89089
# 1   4060   Santa Monica         USA  California       91084
# 2   4057        Visalia         USA  California       91762
# 3   4056      San Mateo         USA  California       91799
# 4   4055   Arden-Arcade         USA  California       92040
# ..   ...            ...         ...         ...         ...
# 63  3826     Long Beach         USA  California      461522
# 64  3805  San Francisco         USA  California      776733
# ...

# %%
pd.read_sql_query("SELECT * FROM CITY WHERE NAME = 'CHICAGO' OR DISTRICT = 'CHICAGO'  AND COUNTRYCODE = 'USA' ",conn)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10772\2099413642.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM CITY WHERE NAME = 'CHICAGO' OR DISTRICT = 'CHICAGO'  AND COUNTRYCODE = 'USA' ",conn)
#      ID     Name CountryCode  District  Population
# 0  3795  Chicago         USA  Illinois     2896016

# %%
pd.read_sql_query("SELECT * FROM COUNTRY WHERE CONTINENT = 'NORTH AMERICA' AND NAME = 'UNITED STATES' ", conn)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10772\9353000.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM COUNTRY WHERE CONTINENT = 'NORTH AMERICA' AND NAME = 'UNITED STATES' ", conn)
#   Code           Name      Continent         Region  SurfaceArea  IndepYear  \
# 0  USA  United States  North America  North America    9363520.0       1776
#
#    Population  LifeExpectancy        GNP     GNPOld      LocalName  \
# 0   278357000            77.1  8510700.0  8110900.0  United States
#
#      GovernmentForm     HeadOfState  Capital Code2
# 0  Federal Republic  George W. Bush     3813    US

# %%
pd.read_sql_query("SELECT * FROM COUNTRY WHERE CONTINENT = 'EUROPE' AND REGION = 'Southern EUROPE' AND LOCALNAME = 'ITALIA' ",conn)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10772\1714612265.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM COUNTRY WHERE CONTINENT = 'EUROPE' AND REGION = 'Southern EUROPE' AND LOCALNAME = 'ITALIA' ",conn)
#   Code   Name Continent           Region  SurfaceArea  IndepYear  Population  \
# 0  ITA  Italy    Europe  Southern Europe     301316.0       1861    57680000
#
#    LifeExpectancy        GNP     GNPOld LocalName GovernmentForm  \
# 0            79.0  1161755.0  1145372.0    Italia       Republic
#
#             HeadOfState  Capital Code2
# 0  Carlo Azeglio Ciampi     1464    IT
